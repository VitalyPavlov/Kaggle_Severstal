# %%
with open('./weights_and_logs/logs_1.txt','r') as f:
    logs = f.read()

logs = logs.split('\n')

metrics_1 = [float(x.split(' ')[-1]) for x in logs[:-1]]
train_loss_1 = [float(x.split(' ')[1]) for x in logs[:-1]]
val_loss_1 = [float(x.split(' ')[3]) for x in logs[:-1]]

# %% [markdown]
# ### efficientnet adam lr=4e-4 exponential_LR 0.9 reduceLRonPlateau 5

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,3))
plt.subplot(1,2,1); plt.plot(metrics_1)
plt.subplot(1,2,2)
plt.plot(train_loss_1, '.-', label='train_loss')
plt.plot(val_loss_1, '.-', label='val_loss')
plt.legend();

# %%
with open('./weights_and_logs/logs_2.txt','r') as f:
    logs = f.read()

logs = logs.split('\n')

metrics_2 = [float(x.split(' ')[-1]) for x in logs[:-1]]
train_loss_2 = [float(x.split(' ')[1]) for x in logs[:-1]]
val_loss_2 = [float(x.split(' ')[3]) for x in logs[:-1]]

# %% [markdown]
# ### efficientnet adam lr=4e-4 reduceLRonPlateau 10

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,3))
plt.subplot(1,2,1); plt.plot(metrics_2)
plt.subplot(1,2,2)
plt.plot(train_loss_2, '.-', label='train_loss')
plt.plot(val_loss_2, '.-', label='val_loss')
plt.legend();

# %%
plt.figure(figsize=(17,3))
plt.subplot(1,3,1)
plt.plot(metrics_1, label='ExponentialLR(g=0.9)')
plt.plot(metrics_2, label='ReduceLROnPlateau(s=10,f=0.25)')
plt.title('dice_metrics')
plt.legend();
plt.subplot(1,3,2)
plt.plot(train_loss_1, '.-', label='ExponentialLR(g=0.9)')
plt.plot(train_loss_2, '.-', label='ReduceLROnPlateau(s=10,f=0.25)')
plt.title('train_loss')
plt.legend();
plt.subplot(1,3,3)
plt.plot(val_loss_1, '.-', label='ExponentialLR(g=0.9)')
plt.plot(val_loss_2, '.-', label='ReduceLROnPlateau(s=10,f=0.25)')
plt.title('val_loss')
plt.legend();

# %%
0.9**100
# Out:
# 2.6561398887587544e-05

# %%
with open('./weights_and_logs/logs_3.txt','r') as f:
    logs = f.read()

logs = logs.split('\n')

metrics_3 = [float(x.split(' ')[-1]) for x in logs[:-1]]
train_loss_3 = [float(x.split(' ')[1]) for x in logs[:-1]]
val_loss_3 = [float(x.split(' ')[3]) for x in logs[:-1]]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,3))
plt.subplot(1,2,1); plt.plot(metrics_3)
plt.subplot(1,2,2)
plt.plot(train_loss_3, '.-', label='train_loss')
plt.plot(val_loss_3, '.-', label='val_loss')
plt.legend();

# %%
plt.figure(figsize=(17,3))
plt.subplot(1,3,1)
plt.plot(metrics_1, label='ExponentialLR(g=0.9)')
plt.plot(metrics_2, label='ReduceLROnPlateau(s=10,f=0.25)')
plt.plot(metrics_3, label='ExponentialLR(g=0.95)')
plt.title('dice_metrics')
plt.legend();
plt.subplot(1,3,2)
plt.plot(train_loss_1, '.-', label='ExponentialLR(g=0.9)')
plt.plot(train_loss_2, '.-', label='ReduceLROnPlateau(s=10,f=0.25)')
plt.plot(train_loss_3, '.-', label='ExponentialLR(g=0.95)')
plt.title('train_loss')
plt.legend();
plt.subplot(1,3,3)
plt.plot(val_loss_1, '.-', label='ExponentialLR(g=0.9)')
plt.plot(val_loss_2, '.-', label='ReduceLROnPlateau(s=10,f=0.25)')
plt.plot(val_loss_3, '.-', label='ExponentialLR(g=0.95)')
plt.title('val_loss')
plt.legend();

# %%
with open('./weights_and_logs/logs_4.txt','r') as f:
    logs = f.read()

logs = logs.split('\n')

metrics_4 = [float(x.split(' ')[-1]) for x in logs[:-1]]
train_loss_4 = [float(x.split(' ')[1]) for x in logs[:-1]]
val_loss_4 = [float(x.split(' ')[3]) for x in logs[:-1]]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,3))
plt.subplot(1,2,1); plt.plot(metrics_4)
plt.subplot(1,2,2)
plt.plot(train_loss_4, '.-', label='train_loss')
plt.plot(val_loss_4, '.-', label='val_loss')
plt.legend();

# %%
plt.figure(figsize=(17,3))
plt.subplot(1,3,1)
plt.plot(metrics_1, label='ExponentialLR(g=0.9)')
plt.plot(metrics_2, label='ReduceLROnPlateau(s=10,f=0.25)')
plt.plot(metrics_3, label='ExponentialLR(g=0.95)')
plt.plot(metrics_4, label='ReduceLROnPlateau(s=7,f=0.25)')
plt.title('dice_metrics')
plt.legend();
plt.subplot(1,3,2)
plt.plot(train_loss_1, '.-', label='ExponentialLR(g=0.9)')
plt.plot(train_loss_2, '.-', label='ReduceLROnPlateau(s=10,f=0.25)')
plt.plot(train_loss_3, '.-', label='ExponentialLR(g=0.95)')
plt.plot(train_loss_4, '.-', label='ReduceLROnPlateau(s=7,f=0.25)')
plt.title('train_loss')
plt.legend();
plt.subplot(1,3,3)
plt.plot(val_loss_1, '.-', label='ExponentialLR(g=0.9)')
plt.plot(val_loss_2, '.-', label='ReduceLROnPlateau(s=10,f=0.25)')
plt.plot(val_loss_3, '.-', label='ExponentialLR(g=0.95)')
plt.plot(val_loss_4, '.-', label='ReduceLROnPlateau(s=7,f=0.25)')
plt.title('val_loss')
plt.legend();

# %%
with open('../segmentation_pytorch/weights_and_logs/logs.txt','r') as f:
    logs = f.read()

logs = logs.split('\n')

metrics_3 = [float(x.split(' ')[-1]) for x in logs[:-1]][100:]
train_loss_3 = [float(x.split(' ')[1]) for x in logs[:-1]][100:]

# %%
with open('../segmentation_pytorch_softmax/weights_and_logs/logs.txt','r') as f:
    logs = f.read()

logs = logs.split('\n')

metrics_4 = [float(x.split(' ')[-1]) for x in logs[:-1]]
train_loss_4 = [float(x.split(' ')[1]) for x in logs[:-1]]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14,3))
plt.subplot(1,2,1); 
plt.plot(metrics_3, label='simoid')
plt.plot(metrics_4, label='softmax')
plt.legend();
plt.subplot(1,2,2)
plt.plot(train_loss_3, '.-', label='simoid')
plt.plot(train_loss_4, '.-', label='softmax')
plt.legend();
plt.show()
